# %%
from pprint import pprint
import datetime
import pandas as pd

import os
import sys
CURR_DIR = os.path.dirname(os.path.realpath('__file__'))
sys.path.append(os.path.dirname(CURR_DIR))
from modules.Parkrun import Parkrun
from modules.Parkrunner import Parkrunner

# %%
pd.to_datetime(datetime.datetime.now())
# Out:
# Timestamp('2023-02-10 19:55:11.283621')

# %% [markdown]
# # Parkrunner

# %%
athlete_id = '4360023'
parkrunner = Parkrunner(athlete_id)

# %%
pprint(parkrunner.other_info)
# Out:
# {'athlete_name': 'Sota MAEHARA',
#  'last_age_category': 'SM20-24',
#  'milestone_club': '50',
#  'nbr_parkruns': '50'}

# %%
pprint(parkrunner.tables)
# Out:
# {'all_results':                              Event   Run Date  Run Number  Pos   Time  \
# 49                       Curl Curl 2018-03-03         254   15  19:27
# 48                      Parramatta 2018-04-07         272    3  18:19
# 47                      Parramatta 2018-05-12         277   11  18:19
# 46                      Parramatta 2018-11-03         302    6  18:46
# 45                          Rhodes 2019-04-20         213    5  18:40
# 44                          Rhodes 2019-04-27         214    7  18:59
# 43                          Rhodes 2019-05-04         215   14  20:11
# 42                          Rhodes 2019-06-01         219  135  27:31
# 41                          Rhodes 2019-06-15         221    6  18:15
# 40                  Futakotamagawa 2019-06-29          13    4  18:36
# 39                          Rhodes 2019-08-17         230    9  18:03
# 38                          Rhodes 2019-08-24         231   56  23:15
# 37                          Rhodes 2019-08-31         232    2  17:49
# 36                          Rhodes 2019-09-21         235    4  17:48
# 35                          Rhodes 2019-11-02         241   25  20:03
# 34                          Rhodes 2019-11-09         242   34  19:58
# 33                          Rhodes 2019-11-16         243    5  17:13
# 32                       St Peters 2020-02-15         417    8  18:00
# 31                          Rhodes 2020-02-22         259    1  16:47
# 30                          Rhodes 2020-12-19         263    9  17:30
# 29                     Cooks River 2020-12-26         275    5  17:59
# 28                          Rhodes 2021-01-01         266   38  21:55
# 27                      Parramatta 2021-01-09         380    5  17:27
# 26                          Rhodes 2021-01-16         269   38  20:47
# 25                       St Peters 2021-02-13         425    6  17:51
# 24                        GreenWay 2021-03-06         124   11  18:25
# 23                          Rhodes 2021-03-13         277   14  18:33
# 22                          Rhodes 2021-04-03         280   44  21:16
# 21                          Rhodes 2021-04-10         281   50  22:51
# 20                          Rhodes 2021-04-24         283   11  19:23
# 19                          Lawson 2021-05-29         293    2  18:40
# 18                       St Peters 2021-12-25         445    1  17:14
# 17                      Centennial 2022-01-29          98    1  17:36
# 16                          Rhodes 2022-02-19         301    1  17:09
# 15                       St Peters 2022-04-16         461    2  16:34
# 14                          Rhodes 2022-04-23         310    2  16:38
# 13                  Futakotamagawa 2022-05-07         103    1  16:45
# 12                  Futakotamagawa 2022-05-14         104   10  20:45
# 11                          Lawson 2022-05-21         315    1  19:18
# 10                          Rhodes 2022-06-18         318    1  16:15
# 9                           Rhodes 2022-06-25         319    1  16:03
# 8                           Rhodes 2022-07-30         324    1  16:45
# 7                        St Peters 2022-09-24         484    1  17:07
# 6                        St Peters 2022-11-19         492    2  16:29
# 5                     North Sydney 2022-11-26         172    1  17:48
# 4                           Rhodes 2022-12-03         342    1  15:40
# 3                           Rhodes 2022-12-25         346    1  15:59
# 2                 Wentworth Common 2023-01-01          49    1  17:22
# 1   Jerrabomberra Mountain Reserve 2023-01-14          22    1  18:09
# 0                       Willoughby 2023-02-04         261    1  17:24
#
#    Age Grade  PB?  Time_numeric
# 49    68.55%  NaN     19.450000
# 48    72.79%  NaN     18.316667
# 47    72.79%  NaN     18.316667
# 46    70.25%  NaN     18.766667
# 45    70.63%  NaN     18.666667
# 44    69.45%  NaN     18.983333
# 43    65.32%  NaN     20.183333
# 42    47.37%  NaN     27.516667
# 41    71.42%   PB     18.250000
# 40    70.07%  NaN     18.600000
# 39    72.21%   PB     18.050000
# 38    56.06%  NaN     23.250000
# 37    73.15%   PB     17.816667
# 36    73.22%   PB     17.800000
# 35    65.00%  NaN     20.050000
# 34    65.28%  NaN     19.966667
# 33    75.70%   PB     17.216667
# 32    72.41%  NaN     18.000000
# 31    77.66%   PB     16.783333
# 30    74.00%  NaN     17.500000
# 29    72.01%  NaN     17.983333
# 28    59.09%  NaN     21.916667
# 27    74.21%   PB     17.450000
# 26    62.31%  NaN     20.783333
# 25    72.55%   PB     17.850000
# 24    70.32%  NaN     18.416667
# 23    69.81%  NaN     18.550000
# 22    60.89%  NaN     21.266667
# 21    56.67%  NaN     22.850000
# 20    66.81%  NaN     19.383333
# 19    69.11%  NaN     18.666667
# 18    74.85%   PB     17.233333
# 17    73.30%  NaN     17.600000
# 16    75.22%  NaN     17.150000
# 15    77.87%   PB     16.566667
# 14    77.56%   PB     16.633333
# 13    77.01%   PB     16.750000
# 12    62.17%  NaN     20.750000
# 11    66.84%  NaN     19.300000
# 10    79.38%   PB     16.250000
# 9     80.37%   PB     16.050000
# 8     77.01%  NaN     16.750000
# 7     75.37%  NaN     17.116667
# 6     78.26%   PB     16.483333
# 5     72.47%  NaN     17.800000
# 4     82.34%   PB     15.666667
# 3     80.71%  NaN     15.983333
# 2     74.28%  NaN     17.366667
# 1     71.07%  NaN     18.150000
# 0     74.14%  NaN     17.400000  ,
#  'annual_bests':    Year Best Time Best Age Grading
# 0  2018  00:18:19           72.79%
# 1  2019  00:17:13           75.70%
# 2  2020  00:16:47           77.66%
# 3  2021  00:17:14           74.85%
# 4  2022  00:15:40           82.34%
# 5  2023  00:17:22           74.28%,
#  'summary_stats':          Unnamed: 0 Fastest Average (mean) Slowest
# 0              Time   15:40          18:31   27:31
# 1       Age Grading  82.34%         70.95%  47.37%
# 2  Overall Position       1          12.28     135}

# %% [markdown]
# Plot of parkrun finishing times over time
# * can filter to specific parkrun
# * can filter to PBs only

# %%
parkrunner.plot_finishing_times(
    show_num_events = 25
    # filter_parkrun = 'Rhodes',
    # show_PB_only = True
)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\janse\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
parkrunner.plot_finishing_times(
    show_num_events = 25,
    show_PB_only = True
)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\janse\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# Boxplot for distribution of finishing times by parkrun event location

# %%
parkrunner.plot_boxplot_times_by_event(
    order_by = "time"
)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\janse\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# Heatmap of parkrun attendance over time

# %%
parkrunner.plot_heatmap_mthly_attendance()
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\janse\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # Parkrun

# %%
event = "theponds"
parkrun = Parkrun(event)

print(parkrun.event_name)
print(parkrun.latest_results)
# Out:
# The Ponds
#      position             name  n_parkruns  gender  gender_position  \
# 0           1   Jayden WEYMARK          21    Male              1.0
# 1           2   Nicholas FOALE          16    Male              2.0
# 2           3   Sammy SMITHSON          10    Male              3.0
# 3           4      Josh DUNCAN           3    Male              4.0
# 4           5        Taj AVERY         174    Male              5.0
# ..        ...              ...         ...     ...              ...
# 573       574  Melissa BOULDEN         150  Female            222.0
# 574       575     Linda BYRNES           4  Female            223.0
# 575       576      Veni PILLAY         153  Female            224.0
# 576       577     Elise WALKER         103  Female            225.0
# 577       578      Ryan WALKER           7    Male            291.0
#
#                                    club full_age_group age_group age_grade  \
# 0    Hills District Athletic Club (NSW)        SM18-19     18-19    75.62%
# 1    Hills District Athletic Club (NSW)        JM11-14     11-14    77.54%
# 2                                   NaN        JM11-14     11-14    74.39%
# 3                                   NaN        SM30-34     30-34    67.89%
# 4                                   NaN        JM15-17     15-17    72.67%
# ..                                  ...            ...       ...       ...
# 573                                 NaN        VW50-54     50-54    25.39%
# 574                                 NaN        VW50-54     50-54    24.77%
# 575                                 NaN        VW60-64     60-64    26.92%
# 576                  She Runs The Hills        VW40-44     40-44    21.11%
# 577                                 NaN           JM10        10    33% ag
#
#     finish_time curr_pb  finish_time_numeric  curr_pb_numeric
# 0         17:26   17:22            17.433333        17.366667
# 1         18:42   18:42            18.700000        18.700000
# 2         19:04   19:04            19.066667        19.066667
# 3         19:06   19:06            19.100000        19.100000
# 4         19:09   19:09            19.150000        19.150000
# ..          ...     ...                  ...              ...
# 573       59:59   28:52            59.983333        28.866667
# 574       59:59   59:59            59.983333        59.983333
# 575       59:59   33:29            59.983333        33.483333
# 576       59:59   24:44            59.983333        24.733333
# 577       59:59   39:20            59.983333        39.333333
#
# [578 rows x 13 columns]

# %% [markdown]
# Plot distribution of finishing times
# * Can split by gender

# %%
parkrun.plot_dist_finish_times(
    by_gender = False
)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\janse\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
parkrun.plot_dist_finish_times(
    by_gender = True
)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\janse\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# Boxplot for distribution of parkrun finish times
# * Can compare by age group or gender

# %%
parkrun.plot_boxplot_finish_times(
    by = "age_group"
    # by = "gender"
)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\janse\\AppData\\Local\\Programs\\Python\\Python38\\lib\\site-packages\\matplotlib\\pyplot.py'>
